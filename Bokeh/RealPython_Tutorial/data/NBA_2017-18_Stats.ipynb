# %% [markdown]
# # NBA 2017-18 Stats Data
#
# **DESCRIPTION**
#
# Player and team box scores and team standings from the 2017-18 season.
#
# **SOURCE**
#
# [Kaggle - NBA Enhanced Box Score and Standings Stats](https://www.kaggle.com/pablote/nba-enhanced-stats#2017-18_playerBoxScore.csv)
#
# **FILES**
#
# * 2017-18_playerBoxScore.csv
# * 2017-18_teamBoxScore.csv
# * 2017-18_standings.csv

# %% [markdown]
# ----
# ## Imports and Setup

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Data Exploration

# %% [markdown]
# ### Player Box Score Stats

# %%
playerStats = pd.read_csv('2017-18_playerBoxScore.csv')

# %%
playerStats.sample(10)
# Out:
#            gmDate gmTime  seasTyp      playLNm   playFNm teamAbbr teamConf  \
# 16495  2018-02-03  03:30  Regular  Arcidiacono      Ryan      CHI     East
# 15622  2018-01-28  06:00  Regular        James    LeBron      CLE     East
# 15213  2018-01-26  07:30  Regular       Joseph      Cory      IND     East
# 22348  2018-03-19  07:30  Regular      Russell  D'Angelo      BKN     East
# 24071  2018-03-30  09:00  Regular     McLemore       Ben      MEM     West
# 4317   2017-11-14  07:30  Regular       Rozier     Terry      BOS     East
# 11648  2018-01-01  07:30  Regular       Siakam    Pascal      TOR     East
# 24025  2018-03-30  08:00  Regular     Anderson      Ryan      HOU     West
# 17516  2018-02-09  09:00  Regular        Bacon    Dwayne      CHA     East
# 9827   2017-12-20  08:00  Regular    Westbrook   Russell      OKC     West
#
#          teamDiv teamLoc teamRslt     ...      playFT% playORB playDRB  \
# ...

# %%
playerStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26109 entries, 0 to 26108
# Data columns (total 51 columns):
# gmDate        26109 non-null object
# gmTime        26109 non-null object
# seasTyp       26109 non-null object
# playLNm       26109 non-null object
# playFNm       26109 non-null object
# teamAbbr      26109 non-null object
# teamConf      26109 non-null object
# teamDiv       26109 non-null object
# teamLoc       26109 non-null object
# teamRslt      26109 non-null object
# teamDayOff    26109 non-null int64
# offLNm1       26109 non-null object
# offFNm1       26109 non-null object
# offLNm2       26109 non-null object
# offFNm2       26109 non-null object
# offLNm3       26089 non-null object
# offFNm3       26089 non-null object
# playDispNm    26109 non-null object
# playStat      26109 non-null object
# playMin       26109 non-null int64
# playPos       26109 non-null object
# playHeight    26109 non-null int64
# playWeight    26109 non-null int64
# ...

# %%
playerStats.describe()
# Out:
#          teamDayOff       playMin    playHeight    playWeight       playPTS  \
# count  26109.000000  26109.000000  26109.000000  26109.000000  26109.000000
# mean       1.785285     22.752423     78.984488    215.859742     10.018729
# std        1.165622     10.235382      3.376295     24.716482      8.021955
# min        0.000000      0.000000     69.000000    149.000000      0.000000
# 25%        1.000000     16.000000     77.000000    198.000000      4.000000
# 50%        2.000000     24.000000     79.000000    215.000000      9.000000
# 75%        2.000000     31.000000     82.000000    235.000000     15.000000
# max       10.000000     52.000000     87.000000    290.000000     60.000000
#
#             playAST        playTO       playSTL       playBLK        playPF  \
# count  26109.000000  26109.000000  26109.000000  26109.000000  26109.000000
# mean       2.189666      1.291279      0.727718      0.453483      1.870428
# ...

# %% [markdown]
# ### Team Box Score Stats

# %%
teamStats = pd.read_csv('2017-18_teamBoxScore.csv')

# %%
teamStats.sample(10)
# Out:
#           gmDate gmTime  seasTyp     offLNm1   offFNm1     offLNm2  offFNm2  \
# 1724  2018-02-14  10:30  Regular        Wood      Leon       Brown     Tony
# 2102  2018-03-19  07:30  Regular     Workman  Haywoode  Fitzgerald     Kane
# 1488  2018-01-30  07:30  Regular       Mauer       Ken        Wood     Leon
# 1132  2018-01-04  10:30  Regular         Orr      J.T.   Zielinski     Gary
# 16    2017-10-18  08:30  Regular       Tiven      Josh  Richardson    Leroy
# 1108  2018-01-03  07:00  Regular       Kogut     Marat      Nansel    Brett
# 2098  2018-03-19  07:00  Regular  Richardson     Leroy   Zielinski     Gary
# 1683  2018-02-12  07:30  Regular    Williams     James      Corbin     Sean
# 269   2017-11-04  09:00  Regular     Guthrie     David    Holtkamp   Lauren
# 486   2017-11-20  07:00  Regular     Guthrie     David    Stafford  Derrick
#
#         offLNm3   offFNm3 teamAbbr    ...    opptFIC40  opptOrtg  opptDrtg  \
# ...

# %%
print(teamStats.columns.values)
# Out:
# ['gmDate' 'gmTime' 'seasTyp' 'offLNm1' 'offFNm1' 'offLNm2' 'offFNm2'
#  'offLNm3' 'offFNm3' 'teamAbbr' 'teamConf' 'teamDiv' 'teamLoc' 'teamRslt'
#  'teamMin' 'teamDayOff' 'teamPTS' 'teamAST' 'teamTO' 'teamSTL' 'teamBLK'
#  'teamPF' 'teamFGA' 'teamFGM' 'teamFG%' 'team2PA' 'team2PM' 'team2P%'
#  'team3PA' 'team3PM' 'team3P%' 'teamFTA' 'teamFTM' 'teamFT%' 'teamORB'
#  'teamDRB' 'teamTRB' 'teamPTS1' 'teamPTS2' 'teamPTS3' 'teamPTS4'
#  'teamPTS5' 'teamPTS6' 'teamPTS7' 'teamPTS8' 'teamTREB%' 'teamASST%'
#  'teamTS%' 'teamEFG%' 'teamOREB%' 'teamDREB%' 'teamTO%' 'teamSTL%'
#  'teamBLK%' 'teamBLKR' 'teamPPS' 'teamFIC' 'teamFIC40' 'teamOrtg'
#  'teamDrtg' 'teamEDiff' 'teamPlay%' 'teamAR' 'teamAST/TO' 'teamSTL/TO'
#  'opptAbbr' 'opptConf' 'opptDiv' 'opptLoc' 'opptRslt' 'opptMin'
#  'opptDayOff' 'opptPTS' 'opptAST' 'opptTO' 'opptSTL' 'opptBLK' 'opptPF'
#  'opptFGA' 'opptFGM' 'opptFG%' 'oppt2PA' 'oppt2PM' 'oppt2P%' 'oppt3PA'
# ...

# %%
teamStats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 123 entries, gmDate to pace
# dtypes: float64(50), int64(54), object(19)
# memory usage: 2.3+ MB

# %%
teamStats.describe()
# Out:
#            teamMin   teamDayOff      teamPTS      teamAST       teamTO  \
# count  2460.000000  2460.000000  2460.000000  2460.000000  2460.000000
# mean    241.480894     1.787398   106.332927    23.239837    14.291057
# std       6.583839     1.165418    12.065504     5.214414     3.785184
# min     226.000000     0.000000    69.000000     9.000000     3.000000
# 25%     240.000000     1.000000    98.000000    20.000000    12.000000
# 50%     240.000000     2.000000   106.000000    23.000000    14.000000
# 75%     241.000000     2.000000   114.000000    27.000000    17.000000
# max     317.000000    10.000000   149.000000    46.000000    29.000000
#
#            teamSTL      teamBLK       teamPF      teamFGA      teamFGM  \
# count  2460.000000  2460.000000  2460.000000  2460.000000  2460.000000
# mean      7.723577     4.813008    19.851626    86.045122    39.607724
# std       2.928179     2.511461     4.212959     6.863569     5.098001
# ...

# %% [markdown]
# ### Team Standing Stats

# %%
standings = pd.read_csv('2017-18_standings.csv')

# %%
standings.sample(10)
# Out:
#           stDate teamAbbr  rank rankOrd  gameWon  gameLost stk stkType  \
# 711   2017-11-09      ORL     3     3rd        7         4  W1     win
# 325   2017-10-27       SA     3     3rd        4         1  L1    loss
# 2058  2017-12-26       NO     7     7th       17        16  W2     win
# 922   2017-11-16      PHI     5     5th        8         6  W2     win
# 4465  2018-03-22       SA     6     6th       42        30  W5     win
# 3614  2018-02-22      MEM    12    12th       18        38  L7    loss
# 0     2017-10-17      ATL     2     2nd        0         0   -       -
# 4494  2018-03-23      POR     3     3rd       44        28  L2    loss
# 101   2017-10-20      IND     4     4th        1         1  L1    loss
# 2991  2018-01-26      ORL    14    14th       14        33  L1    loss
#
#       stkTot  gameBack    ...      rel%Indx     mov     srs     pw%  \
# 711        1       2.5    ...      0.537050  3.6364  3.1325  0.6197
# ...

# %%
print(standings.columns.values)
# Out:
# ['stDate' 'teamAbbr' 'rank' 'rankOrd' 'gameWon' 'gameLost' 'stk' 'stkType'
#  'stkTot' 'gameBack' 'ptsFor' 'ptsAgnst' 'homeWin' 'homeLoss' 'awayWin'
#  'awayLoss' 'confWin' 'confLoss' 'lastFive' 'lastTen' 'gamePlay'
#  'ptsScore' 'ptsAllow' 'ptsDiff' 'opptGmPlay' 'opptGmWon' 'opptOpptGmPlay'
#  'opptOpptGmWon' 'sos' 'rel%Indx' 'mov' 'srs' 'pw%' 'pyth%13.91'
#  'wpyth13.91' 'lpyth13.91' 'pyth%16.5' 'wpyth16.5' 'lpyth16.5']
